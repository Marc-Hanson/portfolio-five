# %% [markdown]
# # **Data Visualisation**

# %% [markdown]
# ---

# %% [markdown]
# ## Objectives
#
# * The client is interested in predicting if a cherry leaf is healthy or contains powdery mildew.
#
# ## Inputs
#
# * inputs/cherryleaves_dataset/train
# * inputs/cherryleaves_dataset/validate
# * inputs/cherryleaves_dataset/test
#
# ## Outputs
#
# * Images distribution plot in train, validation, and test set.
# * Image augmentation.
# * Class indices to change prediction inference in labels.
# * Machine learning model (creation and training).
# * Save model.
# * Learning curve plot for model performance.
# * Save model evaluation on pkl file.
# * Prediction on the random image file.
#
# ## Additional Comments
#
# * None.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder, to its parent folder.

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/portfolio-five/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory, our new working directory.

# %%
os.chdir(os.path.dirname(current_dir))
print("You have successfully set a new working directory")
# Out:
# You have successfully set a new working directory

# %% [markdown]
# And finally, confirm our new working directory.

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/portfolio-five'

# %% [markdown]
# ---

# %% [markdown]
# # Preparing the workspace

# %% [markdown]
# First we set our input directories using our train, test and validation paths.

# %%
my_data_dir = 'inputs/cherryleaves_dataset/cherry-leaves'
train_path = my_data_dir + '/train'
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# Set our output directory and a version number.

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(current_dir) and version in os.listdir(current_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# Set our label names.

# %%
labels = os.listdir(train_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['healthy', 'powdery_mildew']

# %% [markdown]
# Set our image shape.

# %%
import joblib
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# And import the packages needed for this notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib.image import imread

# %% [markdown]
# ---

# %% [markdown]
# # Image distribution

# %% [markdown]
# We will count the number of images per set and per label, then plot them to  bar chart.

# %%
df_freq = pd.DataFrame([]) 
for folder in ['train', 'validation', 'test']:
  for label in labels:
    df_freq = df_freq._append(
        pd.Series(data={'Set': folder,
                        'Label': label,
                        'Frequency':int(len(os.listdir(my_data_dir+'/'+ folder + '/' + label)))}
                  ),
                  ignore_index=True
        )
    
    print(f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(data=df_freq, x='Set', y='Frequency', hue='Label')
plt.savefig(f'{file_path}/labels_distribution.png', bbox_inches='tight', dpi=150)
plt.show()
# Out:
# * train - healthy: 1472 images
# * train - powdery_mildew: 1472 images
# * validation - healthy: 210 images
# * validation - powdery_mildew: 210 images
# * test - healthy: 422 images
# * test - powdery_mildew: 422 images

# %% [markdown]
# ---

# %% [markdown]
# # Image data augmentation

# %% [markdown]
# We will import the keras image data generator.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-01-20 13:52:24.208846: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Then initialize the image data generator and set our batch size.

# %%
augmented_image_data = ImageDataGenerator(rotation_range=20,
                                          width_shift_range=0.10,
                                          height_shift_range=0.10,
                                          shear_range=0.1,
                                          zoom_range=0.1,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          fill_mode='nearest',
                                          rescale=1./255
                                          )

# %%
batch_size = 20

# %% [markdown]
# Firstly, we will augment the training image data set.

# %%
train_set = augmented_image_data.flow_from_directory(train_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

train_set.class_indices
# Out:
# Found 2944 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# Then augment our validation image data set.

# %%
validation_set = augmented_image_data.flow_from_directory(val_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

validation_set.class_indices
# Out:
# Found 420 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# And lastly augment our test image data set.

# %%
test_set = augmented_image_data.flow_from_directory(test_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

test_set.class_indices
# Out:
# Found 844 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# ---

# %% [markdown]
# # Plot augmented image sets

# %% [markdown]
# We can view our augmented training image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = train_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 256, 256, 3)
# (20, 256, 256, 3)
# (20, 256, 256, 3)

# %% [markdown]
# As well as the augmented validation image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = validation_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 256, 256, 3)
# (20, 256, 256, 3)
# (20, 256, 256, 3)

# %% [markdown]
# And view our augmented test image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = test_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 256, 256, 3)
# (20, 256, 256, 3)
# (20, 256, 256, 3)

# %% [markdown]
# Then save our class_indices as a pkl file.

# %%
joblib.dump(value=train_set.class_indices ,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v1/class_indices.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Model creation

# %% [markdown]
# Import model packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %% [markdown]
# Create model

# %%
def create_tf_model():
    model = Sequential()
    
    # input layer
    model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
    model.add(MaxPooling2D())
    
    # convolutional layers
    model.add(Conv2D(32, (3,3), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Conv2D(16, (3,3), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Flatten())

    # fully connected layer
    model.add(Dense(256, activation='relu'))

    # output
    model.add(Dense(1, activation='sigmoid'))
    model.compile('adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# Model Summary

# %%
create_tf_model().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 16)        0
#  g2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3696625 (14.10 MB)
# Trainable params: 3696625 (14.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %% [markdown]
# Fit model for model training

# %%
model = create_tf_model()
model.fit(train_set,
          epochs=25,
          steps_per_epoch = len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# Epoch 1/25
# 147/147 [==============================] - 361s 2s/step - loss: 0.2931 - accuracy: 0.8711 - val_loss: 0.1312 - val_accuracy: 0.9429
# Epoch 2/25
# 147/147 [==============================] - 335s 2s/step - loss: 0.0773 - accuracy: 0.9781 - val_loss: 0.0470 - val_accuracy: 0.9929
# Epoch 3/25
# 147/147 [==============================] - 349s 2s/step - loss: 0.0417 - accuracy: 0.9904 - val_loss: 0.0186 - val_accuracy: 0.9929
# Epoch 4/25
# 147/147 [==============================] - 366s 2s/step - loss: 0.0529 - accuracy: 0.9853 - val_loss: 0.0229 - val_accuracy: 0.9976
# Epoch 5/25
# 147/147 [==============================] - 330s 2s/step - loss: 0.0516 - accuracy: 0.9853 - val_loss: 0.0295 - val_accuracy: 0.9952
# Epoch 6/25
# 147/147 [==============================] - 355s 2s/step - loss: 0.0257 - accuracy: 0.9935 - val_loss: 0.0066 - val_accuracy: 0.9952
# Epoch 7/25
# 147/147 [==============================] - 337s 2s/step - loss: 0.0279 - accuracy: 0.9894 - val_loss: 0.0825 - val_accuracy: 0.9643
# Epoch 8/25
# 147/147 [==============================] - 355s 2s/step - loss: 0.0630 - accuracy: 0.9795 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 9/25
# 147/147 [==============================] - 365s 2s/step - loss: 0.0274 - accuracy: 0.9908 - val_loss: 0.0080 - val_accuracy: 0.9976
# Epoch 10/25
# 147/147 [==============================] - 380s 3s/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.0050 - val_accuracy: 0.9976
# Epoch 11/25
# 147/147 [==============================] - 373s 3s/step - loss: 0.0403 - accuracy: 0.9853 - val_loss: 0.0165 - val_accuracy: 0.9976

# %% [markdown]
# Save model

# %%
model.save('outputs/v1/powdery_mildew_model.h5')
# Out:
# /home/codeany/.local/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---

# %% [markdown]
# # Model performance and evalutaion

# %% [markdown]
# To evaluate model performance we can plot the loss and validation loss, as well as the accuracy and validation accuracy.

# %% [markdown]
# We will then save these image files to document the models learning curve.

# %%
losses = pd.DataFrame(model.history.history)

losses[['loss','val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png', bbox_inches='tight', dpi=150)
plt.show()

print("\n")
losses[['accuracy','val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# To continue our model evaluation we will load our model.

# %%
from keras.models import load_model
model = load_model('outputs/v1/powdery_mildew_model.h5')

# %% [markdown]
# Evaluate our model, based on our test set.

# %%
evaluation = model.evaluate(test_set)
# Out:
# 43/43 [==============================] - 60s 1s/step - loss: 0.0144 - accuracy: 0.9988

# %% [markdown]
# And save our evaluation as a pkl file.

# %%
joblib.dump(value=evaluation ,
            filename=f"outputs/v1/evaluation.pkl")
# Out:
# ['outputs/v1/evaluation.pkl']

# %% [markdown]
# Then we will check our model can predict using new data, by importing a random image as PIL.

# %%
from tensorflow.keras.preprocessing import image

pointer = 66 
label = labels[0] # select Healthy[0] or Infected[1]

pil_image = image.load_img(test_path + '/'+ label + '/'+ os.listdir(test_path+'/'+ label)[pointer],
                          target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (256, 256), Image mode: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# Convert the image to a tensor array and prepare for prediction.

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# Then print the probability of a correct class prediction.

# %%
pred_proba = model.predict(my_image)[0,0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class =  target_map[pred_proba > 0.5]  

if pred_class == target_map[0]: pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# 1/1 [==============================] - 0s 391ms/step
# 0.9999630696511304
# healthy

# %% [markdown]
# ---

# %% [markdown]
# # Push files to repository.

# %% [markdown]
# Git add

# %%
# !git add .

# %% [markdown]
# Git commit

# %%
# !git commit -m "V1 model, accuracy and validation curve images."
# Out:
# [main 210eed7] V1 model, accuracy and validation curve images.
#  1980 files changed, 2081 insertions(+), 5789 deletions(-)
#  rewrite README.md (97%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/00a8e886-d172-4261-85e2-780b3c50ad4d___JR_HL 4156.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{validation => test}/healthy/02818f40-58e6-4c7d-bfbc-372d89b2045b___JR_HL 4259_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/02818f40-58e6-4c7d-bfbc-372d89b2045b___JR_HL 4259_flipTB.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/0438b691-45f8-4251-83bd-8344656716a1___JR_HL 4152.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/04fa77f5-efe7-4956-b8b0-d446aea2f197___JR_HL 4031.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/06904803-b778-4d54-b7ac-fd3f28cc82d9___JR_HL 9820_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/069996a8-8cdb-4837-a5fe-c5a957b5677a___JR_HL 3938.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{validation => test}/healthy/069996a8-8cdb-4837-a5fe-c5a957b5677a___JR_HL 3938_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/07e3276c-7e86-48ee-96d0-db2a35eb03b1___JR_HL 9835.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/0a0bd696-c093-47ef-866b-7f5a40af3edb___JR_HL 3952.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{validation => test}/healthy/0e2e2f2a-17d6-40fd-b084-0391ad37a19f___JR_HL 9573.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{validation => test}/healthy/11c2887d-1fea-4cf8-8696-325de8aad74a___JR_HL 9890.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/11d25451-c4c7-495d-87a4-9cb08f5934b1___JR_HL 4206_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/135f64b7-91ed-40b5-a27b-9a8a602001ec___JR_HL 9878 copy_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/146525c6-e0e4-4296-b0cc-f08f41bd10b8___JR_HL 9864_flipTB.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/14a76290-53c4-46ab-a171-7f2dbf2b13aa___JR_HL 9685_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/14a76290-53c4-46ab-a171-7f2dbf2b13aa___JR_HL 9685_flipTB.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/15ad69af-6eeb-4c2e-a917-7e0797e5b947___JR_HL 9611.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy/15ad69af-6eeb-4c2e-a917-7e0797e5b947___JR_HL 9611_180deg.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{validation => test}/healthy/15b7d0a2-f9de-436b-92e4-7b1c2993984c___JR_HL 4250_flipTB.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => test}/healthy
JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/e3d5a32d-3567-44f4-8ea2-79b413214a6d___FREC_Pwd.M 5144.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/e3d5a32d-3567-44f4-8ea2-79b413214a6d___FREC_Pwd.M 5144_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/e57a51c0-d0c0-46a1-a298-4c9cfd0337e2___FREC_Pwd.M 4778_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/e62db0eb-95cf-4470-87b8-25e046323c79___FREC_Pwd.M 4766.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/e794c6d4-20ea-4643-87dc-34f87db6cafd___FREC_Pwd.M 4967_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/e816bd35-a4f4-41f9-b761-8803ff323652___FREC_Pwd.M 0559.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/e8d9d6fa-568e-4834-a246-d34e1478c77c___FREC_Pwd.M 4884.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/ea9ddb0e-bde0-4972-b202-8554fb62e348___FREC_Pwd.M 4806_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/ece86642-3e2f-4ba7-8181-ff79e317b7b1___FREC_Pwd.M 4663.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/ef0039cb-e261-4019-86a1-db6287829885___FREC_Pwd.M 0276_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/f310a75d-83cb-49db-9df0-b88971930485___FREC_Pwd.M 5130_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/f34e2369-095d-45a6-8407-0272da9aeaef___FREC_Pwd.M 4920.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/f3ca4413-77d8-4e46-8c5b-399a1d34c8f9___FREC_Pwd.M 0482_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/f4021e21-1d79-4eac-a128-3e67ce8d51b4___FREC_Pwd.M 4896.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/f5ed7117-153e-4e4a-a466-297bdbd1bf37___FREC_Pwd.M 4787_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/f6d3fe59-d384-444b-a906-b7aa8e008c31___FREC_Pwd.M 4852.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/f7d72dfe-0b0c-44a2-96b3-fd588eb10b12___FREC_Pwd.M 0500.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/fc970b2a-101f-46d8-ba74-72fc03d0c85c___FREC_Pwd.M 4634_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/fded10e6-0668-43d4-be77-e091cafc25fd___FREC_Pwd.M 0538.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/fe410980-15d4-472d-b8e6-4fece7d302ee___FREC_Pwd.M 4949_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/ff59e364-f269-4a12-ac5a-be4f1e05dbe3___FREC_Pwd.M 4579_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{train => validation}/powdery_mildew/ffdeb404-b84d-4389-9cc9-e1d3159374fe___FREC_Pwd.M 4625_flipLR.JPG (100%)
#  rename inputs/cherryleaves_dataset/cherry-leaves/{test => validation}/powdery_mildew/fffc6a5c-66f3-4d73-afd2-84862fb83c4f___FREC_Pwd.M 5085_flipLR.JPG (100%)
#  rewrite jupyter_notebooks/03_Modelling_Evaluating.ipynb (90%)
#  rewrite outputs/v1/avg_diff.png (92%)
#  rewrite outputs/v1/avg_var_healthy.png (91%)
#  rewrite outputs/v1/avg_var_powdery_mildew.png (93%)
#  create mode 100644 outputs/v1/model_training_acc.png
#  create mode 100644 outputs/v1/model_training_losses.png

# %% [markdown]
# Git push

# %%
# !git push
# Out:
# Enumerating objects: 74, done.
# Counting objects: 100% (74/74), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (34/34), done.
# Writing objects: 100% (40/40), 42.93 MiB | 4.06 MiB/s, done.
# Total 40 (delta 9), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (9/9), completed with 9 local objects.
# To https://github.com/Marc-Hanson/portfolio-five
#    903ced7..210eed7  main -> main

# %% [markdown]
# ---

# %% [markdown]
# # Model is now trained and can be used to predict. Congratulations!
