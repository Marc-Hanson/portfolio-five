# %% [markdown]
# # **Data Visualisation**

# %% [markdown]
# ---

# %% [markdown]
# ## Objectives
#
# * The client is interested in predicting if a cherry leaf is healthy or contains powdery mildew.
#
# ## Inputs
#
# * inputs/cherryleaves_dataset/train
# * inputs/cherryleaves_dataset/validate
# * inputs/cherryleaves_dataset/test
#
# ## Outputs
#
# * Images distribution plot in train, validation, and test set.
# * Image augmentation.
# * Class indices to change prediction inference in labels.
# * Machine learning model (creation and training).
# * Save model.
# * Learning curve plot for model performance.
# * Save model evaluation on pkl file.
# * Prediction on the random image file.
#
# ## Additional Comments
#
# * ADD COMMENTS!

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder, to its parent folder.

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/portfolio-five/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory, our new working directory.

# %%
os.chdir(os.path.dirname(current_dir))
print("You have successfully set a new working directory")
# Out:
# You have successfully set a new working directory

# %% [markdown]
# And finally, confirm our new working directory.

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/portfolio-five'

# %% [markdown]
# ---

# %% [markdown]
# # Preparing the workspace

# %% [markdown]
# First we set our input directories using our train, test and validation paths.

# %%
my_data_dir = 'inputs/cherryleaves_dataset/cherry-leaves'
train_path = my_data_dir + '/train'
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# Set our output directory and a version number.

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(current_dir) and version in os.listdir(current_dir + '/outputs'):
    print('Old version is already available create a new version.')
    pass
else:
    os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# Set our label names.

# %%
labels = os.listdir(train_path)
print('Label for the images are', labels)
# Out:
# Label for the images are ['healthy', 'powdery_mildew']

# %% [markdown]
# Set our image shape.

# %%
import joblib
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# And import the packages needed for this notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from matplotlib.image import imread
# Out:
# KeyboardInterrupt

# %% [markdown]
# ---

# %% [markdown]
# # Image distribution

# %% [markdown]
# We will count the number of images per set and per label, then plot them to  bar chart.

# %%
df_freq = pd.DataFrame([]) 
for folder in ['train', 'validation', 'test']:
  for label in labels:
    df_freq = df_freq.append(
        pd.Series(data={'Set': folder,
                        'Label': label,
                        'Frequency':int(len(os.listdir(my_data_dir+'/'+ folder + '/' + label)))}
                  ),
                  ignore_index=True
        )
    
    print(f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(data=df_freq, x='Set', y='Frequency', hue='Label')
plt.savefig(f'{file_path}/labels_distribution.png', bbox_inches='tight', dpi=150)
plt.show()
# Out:
# * train - healthy: 1472 images
# * train - powdery_mildew: 1472 images
# * validation - healthy: 210 images
# * validation - powdery_mildew: 210 images
# * test - healthy: 422 images
# * test - powdery_mildew: 422 images

# %% [markdown]
# ---

# %% [markdown]
# # Image data augmentation

# %% [markdown]
# We will import the keras image data generator.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Then initialize the image data generator and set our batch size.

# %%
augmented_image_data = ImageDataGenerator(rotation_range=20,
                                          width_shift_range=0.10,
                                          height_shift_range=0.10,
                                          shear_range=0.1,
                                          zoom_range=0.1,
                                          horizontal_flip=True,
                                          vertical_flip=True,
                                          fill_mode='nearest',
                                          rescale=1./255
                                          )

# %%
batch_size = 20

# %% [markdown]
# Firstly, we will augment the training image data set.

# %%
train_set = augmented_image_data.flow_from_directory(train_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

train_set.class_indices
# Out:
# Found 2944 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# Then augment our validation image data set.

# %%
validation_set = augmented_image_data.flow_from_directory(val_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

validation_set.class_indices
# Out:
# Found 420 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# And lastly augment our test image data set.

# %%
test_set = augmented_image_data.flow_from_directory(test_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

test_set.class_indices
# Out:
# Found 844 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# ---

# %% [markdown]
# # Plot augmented image sets

# %% [markdown]
# We can view our augmented training image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = train_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()

# %% [markdown]
# As well as the augmented validation image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = validation_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()

# %% [markdown]
# And view our augmented test image set.

# %%
for _ in range(3):
    plt.figure(figsize=(2, 2))
    img, label = test_set.next()
    print(img.shape)  
    plt.imshow(img[0])
    plt.show()

# %% [markdown]
# Then save our class_indices as a pkl file.

# %%
joblib.dump(value=train_set.class_indices ,
            filename=f"{file_path}/class_indices.pkl")

# %% [markdown]
# ---

# %% [markdown]
# # Model creation

# %% [markdown]
# Import model packages

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %% [markdown]
# Create model

# %%
def create_tf_model():
    model = Sequential()
    
    # input layer
    model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
    model.add(MaxPooling2D())
    
    # convolutional layers
    model.add(Conv2D(32, (3,3), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Conv2D(16, (3,3), 1, activation='relu'))
    model.add(MaxPooling2D())
    model.add(Flatten())

    # fully connected layer
    model.add(Dense(256, activation='relu'))

    # output
    model.add(Dense(1, activation='sigmoid'))
    model.compile('adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# Model Summary

# %%
create_tf_model().summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 254, 254, 16)      448
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 127, 127, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 125, 125, 32)      4640
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 60, 60, 16)        4624
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 30, 30, 16)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 14400)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               3686656
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %% [markdown]
# Fit model for model training

# %%
model = create_tf_model()
model.fit(train_set,
          epochs=25,
          steps_per_epoch = len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# 2024-01-11 16:51:27.714606: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/25
# 147/147 [==============================] - 279s 1s/step - loss: 0.3053 - accuracy: 0.8642 - val_loss: 0.0798 - val_accuracy: 0.9714
# Epoch 2/25
# 147/147 [==============================] - 217s 1s/step - loss: 0.0472 - accuracy: 0.9829 - val_loss: 0.0996 - val_accuracy: 0.9524
# Epoch 3/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0297 - accuracy: 0.9894 - val_loss: 0.0094 - val_accuracy: 0.9952
# Epoch 4/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.0371 - val_accuracy: 0.9786
# Epoch 5/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 0.0244 - val_accuracy: 0.9905
# Epoch 6/25
# 147/147 [==============================] - 212s 1s/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 7/25
# 147/147 [==============================] - 208s 1s/step - loss: 0.0049 - accuracy: 0.9990 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 8/25
# 147/147 [==============================] - 224s 2s/step - loss: 0.0190 - accuracy: 0.9928 - val_loss: 0.0086 - val_accuracy: 0.9976
# Epoch 9/25
# 147/147 [==============================] - 221s 1s/step - loss: 0.0160 - accuracy: 0.9935 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 10/25
# 147/147 [==============================] - 205s 1s/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 11/25
# 147/147 [==============================] - 217s 1s/step - loss: 0.0162 - accuracy: 0.9938 - val_loss: 0.0162 - val_accuracy: 0.9929
# Epoch 12/25
# 147/147 [==============================] - 223s 2s/step - loss: 0.0183 - accuracy: 0.9952 - val_loss: 0.0065 - val_accuracy: 0.9976

# %% [markdown]
# Save model

# %%
model.save('outputs/v1/powdery_mildew_model.h5')

# %% [markdown]
# ---

# %% [markdown]
# # Model performance and evalutaion

# %% [markdown]
# To evaluate model performance we can plot the loss and validation loss.

# %%
fig = plt.figure()
plt.plot(model.history.history['loss'], color='teal', label='loss')
plt.plot(model.history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# And also, plot the accuracy and validation accuracy.

# %%
fig = plt.figure()
plt.plot(model.history.history['accuracy'], color='teal', label='accuracy')
plt.plot(model.history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# To continue our model evaluation we will load our model.

# %%
from keras.models import load_model
model = load_model('outputs/v1/powdery_mildew_model.h5')
# Out:
# 2024-01-16 17:15:57.720807: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Evaluate our model, based on our test set.

# %%
evaluation = model.evaluate(test_set)
# Out:
# 2024-01-16 17:21:25.391000: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 43/43 [==============================] - 188s 3s/step - loss: 0.0043 - accuracy: 0.9988

# %% [markdown]
# And save our evaluation as a pkl file.

# %%
joblib.dump(value=evaluation ,
            filename=f"outputs/v1/evaluation.pkl")
# Out:
# ['outputs/v1/evaluation.pkl']

# %% [markdown]
# Then we will check our model can predict using new data, by importing a random image as PIL.

# %%
from tensorflow.keras.preprocessing import image

pointer = 66 
label = labels[0] # select Uninfected or Parasitized

pil_image = image.load_img(test_path + '/'+ label + '/'+ os.listdir(test_path+'/'+ label)[pointer],
                          target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# Image shape: (256, 256), Image mode: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# Convert the image to a tensor array and prepare for prediction.

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# (1, 256, 256, 3)

# %% [markdown]
# Then print the probability of a correct class prediction.

# %%
pred_proba = model.predict(my_image)[0,0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class =  target_map[pred_proba > 0.5]  

if pred_class == target_map[0]: pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# 0.9999813058075233
# healthy

# %% [markdown]
# ---

# %% [markdown]
# # Push files to repository.

# %% [markdown]
# Git add

# %%
# !git add .

# %% [markdown]
# Git commit

# %%
# !git commit -m "V1 model, alpha notebook commit."
# Out:
# [main 2d9cf3d] V1 model, alpha notebook commit.
#  4225 files changed, 4829 insertions(+), 291 deletions(-)
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0008f3d3-2f85-4973-be9a-1b520b8b59fc___JR_HL 4092_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/002efba9-09b3-43de-93b7-5c2460185cde___JR_HL 9655.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0048afb8-b950-4c57-9e72-7e26282327ee___JR_HL 9765.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0086a8c7-1440-423e-939d-d0567b1fc4e4___JR_HL 4277.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/011f07d1-8813-4a63-99c7-e274ab5cc261___JR_HL 4165_180deg.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/01958ee7-f585-4956-90aa-a40dc79102d4___JR_HL 9836.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/01958ee7-f585-4956-90aa-a40dc79102d4___JR_HL 9836_180deg.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/02b90e70-80a6-415d-b6a8-07e22dead5c4___JR_HL 9892.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/036b575a-cbe7-45a4-8b97-15b7ecdf3dee___JR_HL 9600_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/04189592-5db7-441e-a831-eaaa2d7f5d21___JR_HL 9867_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/048daa26-d38c-477a-96b8-018b3d4ba386___JR_HL 9767_180deg.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0580bdc7-e60e-4ba9-87dc-1202e57b94aa___JR_HL 4159.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0580bdc7-e60e-4ba9-87dc-1202e57b94aa___JR_HL 4159_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/06904803-b778-4d54-b7ac-fd3f28cc82d9___JR_HL 9820.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/07e3276c-7e86-48ee-96d0-db2a35eb03b1___JR_HL 9835_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/088b245d-2b68-4d2b-b7fe-0e9fc42131d3___JR_HL 4132_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0982e1cc-78e8-4bb0-8969-c534e5b0b14b___JR_HL 4097_flipTB.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/0a1319ef-0cbb-4fcc-8126-9c18813f3bac___JR_HL 4012.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy/10d6609b-e358-456c-801d-942c657ed53e___JR_HL 9482_180deg.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/test/healthy
flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/e8abf13a-ddfe-4dd8-b397-9ac7484279cf___FREC_Pwd.M 0557_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/e93cfbbd-e8ca-46a9-b709-00d28fce4c51___FREC_Pwd.M 0468_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/eaa2a350-ce36-4b52-b259-d71d43ee2dda___FREC_Pwd.M 0353.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/eaa2a350-ce36-4b52-b259-d71d43ee2dda___FREC_Pwd.M 0353_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/ebd78f79-cdae-4d2e-a680-f2bb32631ffd___FREC_Pwd.M 4777_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/ee6035b6-8ac1-49db-8ea5-079ccea4790d___FREC_Pwd.M 4590.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/ef4c52e5-d7d8-4996-b445-42478df2c353___FREC_Pwd.M 0584_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/f42d7be6-3df3-4590-8941-de9634a81215___FREC_Pwd.M 4612_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/f4a3ab38-22b7-4d82-a6a7-b58fccdb13b6___FREC_Pwd.M 0522.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/f5f49058-a1ed-4ea4-ab77-e588914b763e___FREC_Pwd.M 0329_flipLR.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/f7f22a1d-718d-4b6d-ac7a-e0121d97d55e___FREC_Pwd.M 4533.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/fae0ccf9-efd8-47c2-af4d-77a13740e172___FREC_Pwd.M 4779.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/fdfada36-240c-4274-afd3-fc159f236d36___FREC_Pwd.M 4831.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/ff2a06ae-9fc1-4436-bfcd-346a18dd5bfb___FREC_Pwd.M 4840.JPG
#  create mode 100644 inputs/cherryleaves_dataset/cherry-leaves/validation/powdery_mildew/ffdeb404-b84d-4389-9cc9-e1d3159374fe___FREC_Pwd.M 4625.JPG
#  create mode 100644 jupyter_notebooks/.ipynb_checkpoints/01_Data_Collection-checkpoint.ipynb
#  create mode 100644 jupyter_notebooks/.ipynb_checkpoints/02_Data_Visualisation-checkpoint.ipynb
#  create mode 100644 jupyter_notebooks/.ipynb_checkpoints/03_Modelling_Evaluating-checkpoint.ipynb
#  create mode 100644 jupyter_notebooks/01_Data_Collection.ipynb
#  create mode 100644 jupyter_notebooks/02_Data_Visualisation.ipynb
#  create mode 100644 jupyter_notebooks/03_Modelling_Evaluating.ipynb
#  delete mode 100644 jupyter_notebooks/Notebook_Template.ipynb
#  create mode 100644 outputs/v1/avg_diff.png
#  create mode 100644 outputs/v1/avg_var_healthy.png
#  create mode 100644 outputs/v1/avg_var_powdery_mildew.png
#  create mode 100644 outputs/v1/class_indices.pkl
#  create mode 100644 outputs/v1/evaluation.pkl
#  create mode 100644 outputs/v1/image_shape.pkl
#  create mode 100644 outputs/v1/labels_distribution.png
#  create mode 100644 outputs/v1/powdery_mildew_model.h5

# %% [markdown]
# Git push

# %%
# !git push
# Out:
# Enumerating objects: 4245, done.
# Counting objects: 100% (4245/4245), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (4234/4234), done.
# Writing objects: 100% (4241/4241), 91.75 MiB | 5.71 MiB/s, done.
# Total 4241 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 2 local objects.
# To https://github.com/Marc-Hanson/portfolio-five
#    0f51b65..2d9cf3d  main -> main

# %% [markdown]
# ---

# %% [markdown]
# # Model is now trained and can be used to predict. Congratulations!
